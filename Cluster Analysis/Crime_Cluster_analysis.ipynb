# %%
import numpy as np
import pandas as pd
df=pd.read_csv("crime_data.csv")
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# 17       Louisiana    15.4      249        66  22.2
# 18           Maine     2.1       83        51   7.8
# 19        Maryland    11.3      300        67  27.8
# 20   Massachusetts     4.4      149        85  16.3
# 21        Michigan    12.1      255        74  35.1
# 22       Minnesota     2.7       72        66  14.9
# 23     Mississippi    16.1      259        44  17.1
# 24        Missouri     9.0      178        70  28.2
# 25         Montana     6.0      109        53  16.4
# 26        Nebraska     4.3      102        62  16.5
# 27          Nevada    12.2      252        81  46.0
# 28   New Hampshire     2.1       57        56   9.5
# 29      New Jersey     7.4      159        89  18.8
# 30      New Mexico    11.4      285        70  32.1
# 31        New York    11.1      254        86  26.1
# 32  North Carolina    13.0      337        45  16.1
# 33    North Dakota     0.8       45        44   7.3
# 34            Ohio     7.3      120        75  21.4
# 35        Oklahoma     6.6      151        68  20.0
# 36          Oregon     4.9      159        67  29.3
# 37    Pennsylvania     6.3      106        72  14.9
# 38    Rhode Island     3.4      174        87   8.3
# 39  South Carolina    14.4      279        48  22.5
# 40    South Dakota     3.8       86        45  12.8
# 41       Tennessee    13.2      188        59  26.9
# 42           Texas    12.7      201        80  25.5
# 43            Utah     3.2      120        80  22.9
# 44         Vermont     2.2       48        32  11.2
# 45        Virginia     8.5      156        63  20.7
# 46      Washington     4.0      145        73  26.2
# 47   West Virginia     5.7       81        39   9.3
# 48       Wisconsin     2.6       53        66  10.8
# 49         Wyoming     6.8      161        60  15.6

# %%
#finding rows and cols
df.shape
# Out:
# (50, 5)

# %%
# prompt: how to add column name as city for first column

df.rename(columns={df.columns[0]: 'city'}, inplace=True)
df
# Out:
#               city  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# 17       Louisiana    15.4      249        66  22.2
# 18           Maine     2.1       83        51   7.8
# 19        Maryland    11.3      300        67  27.8
# 20   Massachusetts     4.4      149        85  16.3
# 21        Michigan    12.1      255        74  35.1
# 22       Minnesota     2.7       72        66  14.9
# 23     Mississippi    16.1      259        44  17.1
# 24        Missouri     9.0      178        70  28.2
# 25         Montana     6.0      109        53  16.4
# 26        Nebraska     4.3      102        62  16.5
# 27          Nevada    12.2      252        81  46.0
# 28   New Hampshire     2.1       57        56   9.5
# 29      New Jersey     7.4      159        89  18.8
# 30      New Mexico    11.4      285        70  32.1
# 31        New York    11.1      254        86  26.1
# 32  North Carolina    13.0      337        45  16.1
# 33    North Dakota     0.8       45        44   7.3
# 34            Ohio     7.3      120        75  21.4
# 35        Oklahoma     6.6      151        68  20.0
# 36          Oregon     4.9      159        67  29.3
# 37    Pennsylvania     6.3      106        72  14.9
# 38    Rhode Island     3.4      174        87   8.3
# 39  South Carolina    14.4      279        48  22.5
# 40    South Dakota     3.8       86        45  12.8
# 41       Tennessee    13.2      188        59  26.9
# 42           Texas    12.7      201        80  25.5
# 43            Utah     3.2      120        80  22.9
# 44         Vermont     2.2       48        32  11.2
# 45        Virginia     8.5      156        63  20.7
# 46      Washington     4.0      145        73  26.2
# 47   West Virginia     5.7       81        39   9.3
# 48       Wisconsin     2.6       53        66  10.8
# 49         Wyoming     6.8      161        60  15.6

# %%
# Column rename.
df.rename(columns={'Unnamed: 0':'City'}, inplace=True)
df.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %%
# Univariate Analysis
# Get descriptive statistics for a single variable
df.describe()
# Out:
#          Murder     Assault   UrbanPop       Rape
# count  50.00000   50.000000  50.000000  50.000000
# mean    7.78800  170.760000  65.540000  21.232000
# std     4.35551   83.337661  14.474763   9.366385
# min     0.80000   45.000000  32.000000   7.300000
# 25%     4.07500  109.000000  54.500000  15.075000
# 50%     7.25000  159.000000  66.000000  20.100000
# 75%    11.25000  249.000000  77.750000  26.175000
# max    17.40000  337.000000  91.000000  46.000000

# %%
# As a part of the Data cleansing we check the data for any missing/ na values
# null count for columns

null_count_col = df.isnull().sum().value_counts(ascending=False)

# null percentage for columns

null_percent_col = (df.isnull().sum() * 100 / len(df)).value_counts(ascending=False)

print("Null Count for Columns:\n\n", null_count_col, "\n")
print("Null Percentage for Columns:\n\n", null_percent_col)
# Out:
# Null Count for Columns:
#
#  0    5
# dtype: int64
#
# Null Percentage for Columns:
#
#  0.0    5
# dtype: int64

# %%
# Bivariate Analysis
# Get correlation between two variables
df["UrbanPop"].corr(df["Rape"])
# Out:
# 0.4113412356240992

# %%
# Loop through each continious variable and create a histogram
import matplotlib.pyplot as plt
for x_variable in df.select_dtypes(include=["int64"]):
  plt.hist(df[x_variable])
  plt.title("Histogram of " + x_variable)
  plt.show()

# %%
# Loop through each continious variable and create a histogram
import matplotlib.pyplot as plt
for x_variable in df.select_dtypes(include=["float64"]):
  plt.hist(df[x_variable])
  plt.title("Histogram of " + x_variable)
  plt.show()

# %%
#Label Encoding the obj Dtypes
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for column in df.select_dtypes(include=["object"]):
    df[column] = LE.fit_transform(df[column])
df.head()
# Out:
#    city  Murder  Assault  UrbanPop  Rape
# 0     0    13.2      236        58  21.2
# 1     1    10.0      263        48  44.5
# 2     2     8.1      294        80  31.0
# 3     3     8.8      190        50  19.5
# 4     4     9.0      276        91  40.6

# %%
import seaborn as sns
for n in df.columns:
    print(n)
    sns.kdeplot(df[n])
    plt.show()
# Out:
# city
# Murder
# Assault
# UrbanPop
# Rape

# %%
#standardization will fit the values b/w -3 to +3
x=df.iloc[:,:]
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
SS_x = SS.fit_transform(x)
SS_x = pd.DataFrame(SS_x)
#giving columns names to the converted data
SS_x.columns = list(x)
SS_x.head()
# Out:
#        city    Murder   Assault  UrbanPop      Rape
# 0 -1.697749  1.255179  0.790787 -0.526195 -0.003451
# 1 -1.628453  0.513019  1.118060 -1.224067  2.509424
# 2 -1.559158  0.072361  1.493817  1.009122  1.053466
# 3 -1.489862  0.234708  0.233212 -1.084492 -0.186794
# 4 -1.420566  0.281093  1.275635  1.776781  2.088814

# %%
#----------------------------------- K -MEANS CLUSTER ---------------------------------------------------------
x_new=df.iloc[:,3:5]
from sklearn.cluster import KMeans
cluster=KMeans(n_init=20,n_clusters=5)
y=cluster.fit_predict(x_new)
x_new.head()
# Out:
#    UrbanPop  Rape
# 0        58  21.2
# 1        48  44.5
# 2        80  31.0
# 3        50  19.5
# 4        91  40.6

# %%
y=pd.DataFrame(y)
y.value_counts()
# Out:
# 0    18
# 1    14
# 3    10
# 2     7
# 4     1
# dtype: int64

# %%
#seeing clusters in scatter plot
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
plt.scatter(df["UrbanPop"],df["Rape"],c=cluster.labels_,cmap='rainbow')
plt.xlabel("UrbanPop")
plt.ylabel("Rape")
plt.show()

# %%
cluster.inertia_
# Out:
# 2702.6716984126983

# %%
kinertias = []
for i in range(1,11):
  from sklearn.cluster import KMeans
  cluster=KMeans(n_init=20,n_clusters=i)
  cluster.fit_predict(x_new)
  kinertias.append(cluster.inertia_)
kinertias
# Out:
# [14565.148799999999,
#  6720.892,
#  4710.82432330827,
#  3507.734484126985,
#  2702.6716984126983,
#  2235.358214285714,
#  1791.8472265512264,
#  1561.967714285714,
#  1300.7077976190474,
#  1087.530714285714]

# %%
#seeing clusters in scatter plot(Elbow plot)
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
plt.scatter(range(1,11),kinertias)
plt.plot(range(1,11),kinertias,color='red')
plt.show()

# %%
#now do the supervised learning with target variable
df["Target"]=y.values
df.head()
# Out:
#    city  Murder  Assault  UrbanPop  Rape  Target
# 0     0    13.2      236        58  21.2       0
# 1     1    10.0      263        48  44.5       4
# 2     2     8.1      294        80  31.0       2
# 3     3     8.8      190        50  19.5       1
# 4     4     9.0      276        91  40.6       2

# %%
#now do the supervised learning with target variable
df["Target"]=y.values
df.head()
# Out:
#    city  Murder  Assault  UrbanPop  Rape  Target
# 0     0    13.2      236        58  21.2       0
# 1     1    10.0      263        48  44.5       4
# 2     2     8.1      294        80  31.0       2
# 3     3     8.8      190        50  19.5       1
# 4     4     9.0      276        91  40.6       2

# %%
#choosing X and Y variables
y=df["Target"]
x=df.iloc[:,:-1]
x.head()
# Out:
#    city  Murder  Assault  UrbanPop  Rape
# 0     0    13.2      236        58  21.2
# 1     1    10.0      263        48  44.5
# 2     2     8.1      294        80  31.0
# 3     3     8.8      190        50  19.5
# 4     4     9.0      276        91  40.6

# %%
#standardization will fit the values b/w -3 to +3

from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
SS_x = SS.fit_transform(x)
SS_x = pd.DataFrame(SS_x)
#giving columns names to the converted data
SS_x.columns = list(x)
SS_x.head()
# Out:
#        city    Murder   Assault  UrbanPop      Rape
# 0 -1.697749  1.255179  0.790787 -0.526195 -0.003451
# 1 -1.628453  0.513019  1.118060 -1.224067  2.509424
# 2 -1.559158  0.072361  1.493817  1.009122  1.053466
# 3 -1.489862  0.234708  0.233212 -1.084492 -0.186794
# 4 -1.420566  0.281093  1.275635  1.776781  2.088814

# %%
#cross validation method by Logictic regression
#validation set approach
#random state = we wre not shuffling the data
#test_size = 0.30 (train:test = 70:30)
#import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
logrec = LogisticRegression()

training_accuracy = []
test_accuracy = []
for i in range(1,101):
    x_train,x_test,y_train,y_test = train_test_split(SS_x,y,test_size=0.30,random_state=i)
    logrec.fit(x_train,y_train)
    y_pred_train = logrec.predict(x_train)
    y_pred_test = logrec.predict(x_test)
    training_accuracy.append(accuracy_score(y_train,y_pred_train))
    test_accuracy.append(accuracy_score(y_test,y_pred_test))
    ac1=np.mean(training_accuracy)
    ac2=np.mean(test_accuracy)
print("Cross validation trainig score ",np.mean(training_accuracy).round(2))
print("Cross validation test score",np.mean(test_accuracy).round(2))
print("Variance between Training and Testing " ,(ac1-ac2).round(3))
# Out:
# Cross validation trainig score  0.97
# Cross validation test score 0.8
# Variance between Training and Testing  0.167

# %%
#cross validation by KNN
#k=15
#cross validation method
#validation set approach
#random state = we wre not shuffling the data
#test_size = 0.30 (train:test = 70:30)
for i in range(1,21,2):
  from sklearn.model_selection import train_test_split
  from sklearn.metrics import accuracy_score
  from sklearn.neighbors import KNeighborsClassifier
  KNN = KNeighborsClassifier(n_neighbors=i)
  training_accuracy = []
  test_accuracy = []
  for p in range(1,101):
    x_train,x_test,y_train,y_test = train_test_split(SS_x,y,test_size=0.30,random_state=p)
    KNN.fit(x_train,y_train)
    y_pred_train = KNN.predict(x_train)
    y_pred_test = KNN.predict(x_test)
    training_accuracy.append(accuracy_score(y_train,y_pred_train))
    test_accuracy.append(accuracy_score(y_test,y_pred_test))
    ac1=np.mean(training_accuracy)
    ac2=np.mean(test_accuracy)
  print("Cross validation Trainig accuracy for ","k =",i,": ",np.mean(training_accuracy).round(2))
  print("Cross validation Test accuracy for ","k =",i,": ",np.mean(test_accuracy).round(2))
  print("Variance between Training and Testing :","for k=",i,":",(ac1-ac2).round(3))
  print(" ")
# Out:
# Cross validation Trainig accuracy for  k = 1 :  1.0
# Cross validation Test accuracy for  k = 1 :  0.71
# Variance between Training and Testing : for k= 1 : 0.293
#
# Cross validation Trainig accuracy for  k = 3 :  0.89
# Cross validation Test accuracy for  k = 3 :  0.67
# Variance between Training and Testing : for k= 3 : 0.214
#
# Cross validation Trainig accuracy for  k = 5 :  0.78
# Cross validation Test accuracy for  k = 5 :  0.65
# Variance between Training and Testing : for k= 5 : 0.134
#
# Cross validation Trainig accuracy for  k = 7 :  0.74
# Cross validation Test accuracy for  k = 7 :  0.61
# Variance between Training and Testing : for k= 7 : 0.132
#
# Cross validation Trainig accuracy for  k = 9 :  0.7
# Cross validation Test accuracy for  k = 9 :  0.58
# Variance between Training and Testing : for k= 9 : 0.111
#
# Cross validation Trainig accuracy for  k = 11 :  0.64
# Cross validation Test accuracy for  k = 11 :  0.53
# Variance between Training and Testing : for k= 11 : 0.115
#
# Cross validation Trainig accuracy for  k = 13 :  0.58
# Cross validation Test accuracy for  k = 13 :  0.46
# Variance between Training and Testing : for k= 13 : 0.114
#
# Cross validation Trainig accuracy for  k = 15 :  0.51
# Cross validation Test accuracy for  k = 15 :  0.41
# Variance between Training and Testing : for k= 15 : 0.104
#
# Cross validation Trainig accuracy for  k = 17 :  0.47
# Cross validation Test accuracy for  k = 17 :  0.4
# Variance between Training and Testing : for k= 17 : 0.07
#
# Cross validation Trainig accuracy for  k = 19 :  0.44
# Cross validation Test accuracy for  k = 19 :  0.38
# Variance between Training and Testing : for k= 19 : 0.061

# %%
#cross validation method ------------------------- # Decision tree method----------------------------------
#validation set approach
#random state = we wre not shuffling the data
#test_size = 0.30 (train:test = 70:30)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()

training_accuracy = []
test_accuracy = []
for i in range(1,101):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=i)
    dt.fit(x_train,y_train)
    y_pred_train = dt.predict(x_train)
    y_pred_test = dt.predict(x_test)
    training_accuracy.append(accuracy_score(y_train,y_pred_train))
    test_accuracy.append(accuracy_score(y_test,y_pred_test))
    ac1=np.mean(training_accuracy)
    ac2=np.mean(test_accuracy)
print("Cross validation trainig score ",np.mean(training_accuracy).round(3))
print("Cross validation test score",np.mean(test_accuracy).round(3))
print("Variance between Training and Testing :",(ac1-ac2).round(3))
# Out:
# Cross validation trainig score  1.0
# Cross validation test score 0.881
# Variance between Training and Testing : 0.119

# %%
#-------------------Univariate analysis-----------------------------------------------
#constructing box for all x_variables value counts
#Visualizing the data
import matplotlib.pyplot as plt
plt.boxplot(SS_x,vert=False)
plt.title("Box plot for each x variable")
plt.ylabel("values")
plt.show()

# %%
##Bar graph for every x- variable with Murder
import seaborn as sns
import matplotlib.pyplot as plt
for column in df.select_dtypes(include=["int64"]):
  sns.barplot(x=df['city'], y=df[column])
  plt.show()

# %%
#Scatter plot for each pair of features
for i, column1 in enumerate(df.select_dtypes(include=["int64"])):
    for column2 in df.select_dtypes(include=["int64"])[i+1:]:
        sns.scatterplot(x=df[column1], y=df[column2])#, hue=df['ShelveLoc'])
        plt.show()

# %%
# ------------------------------------------- DBSCAN -----------------------------------------------------------
#Our DBSCAN cluster analysis not only used for forming clusters but also used for
#Identifying outlayers

# %%
df.drop("Target", axis=1, inplace=True)

# %%
from sklearn.cluster import DBSCAN
DBSCAN()
dbscan = DBSCAN(eps=0.75,min_samples=3)
dbscan.fit(SS_x)
# Out:
# DBSCAN(eps=0.75, min_samples=3)

# %%
#here DBSCAN itself decides how many clusters are suitable
# if we got (-1) as a lable it means it is a noisy data point ==> outlayer

y= dbscan.labels_
y=pd.DataFrame(y)
y.value_counts()
# Out:
# -1    47
#  0     3
# dtype: int64

# %%
#removing outlayers from y
df["clusters"] = y

# %%
#.copy() is used at the end of the main dataframe
df_new = df[df["clusters"] != 0]
df_new.head()
# Out:
#    city  Murder  Assault  UrbanPop  Rape  clusters
# 0     0    13.2      236        58  21.2        -1
# 1     1    10.0      263        48  44.5        -1
# 2     2     8.1      294        80  31.0        -1
# 3     3     8.8      190        50  19.5        -1
# 4     4     9.0      276        91  40.6        -1

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   city      47 non-null     int64
#  1   Murder    47 non-null     float64
#  2   Assault   47 non-null     int64
#  3   UrbanPop  47 non-null     int64
#  4   Rape      47 non-null     float64
#  5   clusters  47 non-null     int64
# dtypes: float64(2), int64(4)
# memory usage: 2.6 KB

# %%
x_new=df_new.iloc[:,3:5]
from sklearn.cluster import KMeans
cluster=KMeans(n_init=20,n_clusters=5)
y=cluster.fit_predict(x_new)
y
# Out:
# array([2, 4, 0, 1, 0, 0, 3, 2, 0, 2, 3, 1, 3, 2, 1, 2, 1, 2, 1, 2, 3, 0,
#        1, 2, 0, 1, 3, 0, 3, 1, 1, 3, 2, 2, 2, 3, 1, 1, 2, 3, 3, 1, 2, 2,
#        1, 2, 2], dtype=int32)

# %%
y=pd.DataFrame(y)
y.value_counts()
# Out:
# 2    16
# 1    13
# 3    10
# 0     7
# 4     1
# dtype: int64

# %%
#seeing clusters in scatter plot
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
plt.scatter(df_new["UrbanPop"],df_new["Rape"],c=cluster.labels_,cmap='rainbow')
plt.xlabel("X-LABEL")
plt.ylabel("Y-LABEL")
plt.show()

# %%
cluster.inertia_
# Out:
# 2591.0827912087907

# %%
#Inertias for elbow plot
kinertias = []
for i in range(1,11):
  from sklearn.cluster import KMeans
  cluster=KMeans(n_init=20,n_clusters=i)
  cluster.fit_predict(x_new)
  kinertias.append(cluster.inertia_)
kinertias
# Out:
# [14298.752340425533,
#  6436.3879259259265,
#  4563.2089592760185,
#  3327.516618589744,
#  2591.0827912087907,
#  2123.8318333333327,
#  1756.256888888889,
#  1516.2529404761904,
#  1249.2866666666666,
#  998.3084126984127]

# %%
#making with k - means cluster
from sklearn.cluster import KMeans
cluster=KMeans(n_init=20,n_clusters=5)
y_kmens=cluster.fit_predict(x_new)
y_kmens
# Out:
# array([0, 4, 3, 1, 3, 3, 2, 0, 3, 0, 2, 1, 2, 0, 1, 0, 1, 0, 1, 0, 2, 3,
#        1, 0, 3, 1, 2, 3, 2, 1, 1, 2, 0, 0, 0, 2, 1, 1, 0, 2, 2, 1, 0, 0,
#        1, 0, 0], dtype=int32)

# %%
y_kmens=pd.DataFrame(y_kmens)
y_kmens.value_counts()
print(len(y_kmens))
print(len(df_new))
#y_kmens.tail()
# Out:
# 47
# 47

# %%
#seeing Inertias in scatter/screw/elbow plot
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
plt.scatter(range(1,11),kinertias)
plt.plot(range(1,11),kinertias,color='red')
plt.show()

# %%
df_new.loc[:, 'Target'] = y_kmens.values
df_new["Target"]
# Out:
# <ipython-input-85-c497b6f2453b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.loc[:, 'Target'] = y_kmens.values
# 0     0
# 1     4
# 2     3
# 3     1
# 4     3
# 5     3
# 6     2
# 7     0
# 8     3
# 9     0
# 10    2
# 11    1
# 12    2
# 13    0
# 14    1
# 15    0
# 16    1
# 17    0
# 18    1
# 19    0
# 20    2
# 21    3
# 23    1
# 24    0
# 27    3
# 28    1
# 29    2
# 30    3
# 31    2
# 32    1
# 33    1
# 34    2
# 35    0
# 36    0
# 37    0
# 38    2
# 39    1
# 40    1
# 41    0
# 42    2
# 43    2
# 44    1
# 45    0
# 46    0
# 47    1
# 48    0
# 49    0
# Name: Target, dtype: int32

# %%
df_new.tail()
# Out:
#     city  Murder  Assault  UrbanPop  Rape  clusters  Target
# 45    45     8.5      156        63  20.7        -1       0
# 46    46     4.0      145        73  26.2        -1       0
# 47    47     5.7       81        39   9.3        -1       1
# 48    48     2.6       53        66  10.8        -1       0
# 49    49     6.8      161        60  15.6        -1       0

# %%
#choosing X and Y variables
y=df_new["Target"]
x=df_new.iloc[:,0:-2]
x.head()
# Out:
#    city  Murder  Assault  UrbanPop  Rape
# 0     0    13.2      236        58  21.2
# 1     1    10.0      263        48  44.5
# 2     2     8.1      294        80  31.0
# 3     3     8.8      190        50  19.5
# 4     4     9.0      276        91  40.6

# %%
#standardization will fit the values b/w -3 to +3

from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
SS_x = SS.fit_transform(x)
SS_x = pd.DataFrame(SS_x)
#giving columns names to the converted data
SS_x.columns = list(x)
SS_x.head()
# Out:
#        city    Murder   Assault  UrbanPop      Rape
# 0 -1.647437  1.195694  0.730510 -0.537255 -0.039128
# 1 -1.580223  0.458676  1.057270 -1.219715  2.423461
# 2 -1.513010  0.021072  1.432439  0.964155  0.996639
# 3 -1.445797  0.182294  0.173808 -1.083223 -0.218802
# 4 -1.378584  0.228358  1.214599  1.714861  2.011268

# %%
#cross validation method ------------------------- # Decision tree method----------------------------------
#validation set approach
#random state = we wre not shuffling the data
#test_size = 0.30 (train:test = 70:30)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()

training_accuracy = []
test_accuracy = []
for i in range(1,101):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=i)
    dt.fit(x_train,y_train)
    y_pred_train = dt.predict(x_train)
    y_pred_test = dt.predict(x_test)
    training_accuracy.append(accuracy_score(y_train,y_pred_train))
    test_accuracy.append(accuracy_score(y_test,y_pred_test))
    ac1=np.mean(training_accuracy)
    ac2=np.mean(test_accuracy)
print("Cross validation trainig score ",np.mean(training_accuracy).round(3))
print("Cross validation test score",np.mean(test_accuracy).round(3))
print("Variance between Training and Testing :",(ac1-ac2).round(3))
# Out:
# Cross validation trainig score  1.0
# Cross validation test score 0.878
# Variance between Training and Testing : 0.122

# %%
# DBSCAN giving the better results, as it helps in removing the outliers
