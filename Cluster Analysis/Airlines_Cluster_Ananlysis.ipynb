# %%
import numpy as np
import pandas as pd
df=pd.read_excel("EastWestAirlines.xlsx",sheet_name='data')
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
#finding rows and cols
df.shape
# Out:
# (3999, 12)

# %%
# Column rename.
df.rename(columns={'ID#':'ID', 'Award?':'Award'}, inplace=True)
df
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
#Set ID as Index Column
df.set_index('ID',inplace=True)
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID
# ...

# %%
#first 5 rows
df.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1     28143           0          1          1          1          174
# 2     19244           0          1          1          1          215
# 3     41354           0          1          1          1         4123
# 4     14776           0          1          1          1          500
# 5     97752           0          4          1          1        43300
#
#     Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# ID
# 1             1                  0                0               7000      0
# 2             2                  0                0               6968      0
# 3             4                  0                0               7034      0
# 4             1                  0                0               6952      0
# 5            26               2077                4               6935      1

# %%
# Univariate Analysis
# Get descriptive statistics for a single variable
df.describe()
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %%
# As a part of the Data cleansing we check the data for any missing/ na values
# null count for columns

null_count_col = df.isnull().sum().value_counts(ascending=False)

# null percentage for columns

null_percent_col = (df.isnull().sum() * 100 / len(df)).value_counts(ascending=False)

print("Null Count for Columns:\n\n", null_count_col, "\n")
print("Null Percentage for Columns:\n\n", null_percent_col)
# Out:
# Null Count for Columns:
#
#  0    11
# dtype: int64
#
# Null Percentage for Columns:
#
#  0.0    11
# dtype: int64

# %%
# null count for rows

null_count_row = df.isnull().sum(axis=1).value_counts(ascending=False)

# null percentage for rows

null_percent_row = (df.isnull().sum(axis=1) * 100 / len(df)).value_counts(ascending=False)

print("Null Count for Rows:\n\n", null_count_row, "\n")
print("Null Percentage for Rows:\n\n", null_percent_row)
# Out:
# Null Count for Rows:
#
#  0    3999
# dtype: int64
#
# Null Percentage for Rows:
#
#  0.0    3999
# dtype: int64

# %%
# Additionally we check the data for any duplicate values, now this can be an optional check depending on the data being used
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 3899     1000           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID
# 3899            0                  0                0               1597
#
#       Award
# ID
# 3899      0

# %%
# Bivariate Analysis
# Get correlation between two variables
df["cc1_miles"].corr(df["Bonus_miles"])
# Out:
# 0.8252001562475547

# %%
#Plotting histogram for two variables
df[['cc1_miles','Bonus_miles']].hist()
# Out:
# array([[<Axes: title={'center': 'cc1_miles'}>,
#         <Axes: title={'center': 'Bonus_miles'}>]], dtype=object)

# %%
# Loop through each continious variable and create a histogram
import matplotlib.pyplot as plt
for x_variable in df.select_dtypes(include=["int64"]):
  plt.hist(df[x_variable])
  plt.title("Histogram of " + x_variable)
  plt.show()

# %%
import seaborn as sns
for n in df.columns:
    print(n)
    sns.kdeplot(df[n])
    plt.show()
# Out:
# Balance
# Qual_miles
# cc1_miles
# cc2_miles
# cc3_miles
# Bonus_miles
# Bonus_trans
# Flight_miles_12mo
# Flight_trans_12
# Days_since_enroll
# Award

# %%
#standardization will fit the values b/w -3 to +3
x=df.iloc[:,:]
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
SS_x = SS.fit_transform(x)
SS_x = pd.DataFrame(SS_x)
#giving columns names to the converted data
SS_x.columns = list(x)
SS_x.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4  0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0    -1.104065          -0.328603        -0.362168           1.395454
# 1    -0.999926          -0.328603        -0.362168           1.379957
# 2    -0.791649          -0.328603        -0.362168           1.411920
# 3    -1.104065          -0.328603        -0.362168           1.372208
# 4     1.499394           1.154932         0.692490           1.363975
#
#       Award
# 0 -0.766919
# 1 -0.766919
# 2 -0.766919
# 3 -0.766919
# 4  1.303918

# %%
#----------------------------------- K -MEANS CLUSTER ---------------------------------------------------------
x_new=df.iloc[:,0:2]
from sklearn.cluster import KMeans
cluster=KMeans(n_init=20,n_clusters=5)
y=cluster.fit_predict(x_new)

# %%
y=pd.DataFrame(y)
y.value_counts()
# Out:
# 0    2502
# 3    1048
# 1     342
# 4      88
# 2      19
# dtype: int64

# %%
#seeing clusters in scatter plot
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
plt.scatter(x_new.iloc[:,0],x_new.iloc[:,1],c=cluster.labels_,cmap='rainbow')
plt.xlabel("X-LABEL")
plt.ylabel("Y-LABEL")
plt.show()

# %%
cluster.inertia_
# Out:
# 5724556335991.386

# %%
kinertias = []
for i in range(1,11):
  from sklearn.cluster import KMeans
  cluster=KMeans(n_init=20,n_clusters=i)
  cluster.fit_predict(x_new)
  kinertias.append(cluster.inertia_)
kinertias
# Out:
# [40605020147446.45,
#  18670944288737.973,
#  9786629688652.086,
#  5654613329630.979,
#  3873948233266.455,
#  2726980161964.2344,
#  1894895057229.3003,
#  1524262500580.5083,
#  1235898313104.8608,
#  993218410688.8566]

# %%
#seeing clusters in scatter plot(Elbow plot)
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
plt.scatter(range(1,11),kinertias)
plt.plot(range(1,11),kinertias,color='red')
plt.show()

# %%
#now do the supervised learning with target variable
df["Target"]=y.values
df.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1     28143           0          1          1          1          174
# 2     19244           0          1          1          1          215
# 3     41354           0          1          1          1         4123
# 4     14776           0          1          1          1          500
# 5     97752           0          4          1          1        43300
#
#     Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# ID
# 1             1                  0                0               7000      0
# 2             2                  0                0               6968      0
# 3             4                  0                0               7034      0
# 4             1                  0                0               6952      0
# 5            26               2077                4               6935      1
#
#     Target
# ID
# 1        0
# 2        0
# 3        0
# ...

# %%
df["Target"]
# Out:
# ID
# 1       0
# 2       0
# 3       0
# 4       0
# 5       3
#        ..
# 4017    0
# 4018    0
# 4019    3
# 4020    0
# 4021    0
# Name: Target, Length: 3999, dtype: int32

# %%
#now do the supervised learning with target variable
df["Target"]=y.values
df.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1     28143           0          1          1          1          174
# 2     19244           0          1          1          1          215
# 3     41354           0          1          1          1         4123
# 4     14776           0          1          1          1          500
# 5     97752           0          4          1          1        43300
#
#     Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# ID
# 1             1                  0                0               7000      0
# 2             2                  0                0               6968      0
# 3             4                  0                0               7034      0
# 4             1                  0                0               6952      0
# 5            26               2077                4               6935      1
#
#     Target
# ID
# 1        0
# 2        0
# 3        0
# ...

# %%
#Label Encoding the obj Dtypes
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for column in df.select_dtypes(include=["object"]):
    df[column] = LE.fit_transform(df[column])
df.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1     28143           0          1          1          1          174
# 2     19244           0          1          1          1          215
# 3     41354           0          1          1          1         4123
# 4     14776           0          1          1          1          500
# 5     97752           0          4          1          1        43300
#
#     Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# ID
# 1             1                  0                0               7000      0
# 2             2                  0                0               6968      0
# 3             4                  0                0               7034      0
# 4             1                  0                0               6952      0
# 5            26               2077                4               6935      1
#
#     Target
# ID
# 1        0
# 2        0
# 3        0
# ...

# %%
#choosing X and Y variables
y=df["Target"]
x=df.iloc[:,:-1]
x.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1     28143           0          1          1          1          174
# 2     19244           0          1          1          1          215
# 3     41354           0          1          1          1         4123
# 4     14776           0          1          1          1          500
# 5     97752           0          4          1          1        43300
#
#     Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# ID
# 1             1                  0                0               7000      0
# 2             2                  0                0               6968      0
# 3             4                  0                0               7034      0
# 4             1                  0                0               6952      0
# 5            26               2077                4               6935      1

# %%
#standardization will fit the values b/w -3 to +3

from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
SS_x = SS.fit_transform(x)
SS_x = pd.DataFrame(SS_x)
#giving columns names to the converted data
SS_x.columns = list(x)
SS_x.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4  0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0    -1.104065          -0.328603        -0.362168           1.395454
# 1    -0.999926          -0.328603        -0.362168           1.379957
# 2    -0.791649          -0.328603        -0.362168           1.411920
# 3    -1.104065          -0.328603        -0.362168           1.372208
# 4     1.499394           1.154932         0.692490           1.363975
#
#       Award
# 0 -0.766919
# 1 -0.766919
# 2 -0.766919
# 3 -0.766919
# 4  1.303918

# %%
#cross validation method by Logictic regression
#validation set approach
#random state = we wre not shuffling the data
#test_size = 0.30 (train:test = 70:30)
#import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
logrec = LogisticRegression()

training_accuracy = []
test_accuracy = []
for i in range(1,101):
    x_train,x_test,y_train,y_test = train_test_split(SS_x,y,test_size=0.30,random_state=i)
    logrec.fit(x_train,y_train)
    y_pred_train = logrec.predict(x_train)
    y_pred_test = logrec.predict(x_test)
    training_accuracy.append(accuracy_score(y_train,y_pred_train))
    test_accuracy.append(accuracy_score(y_test,y_pred_test))
    ac1=np.mean(training_accuracy)
    ac2=np.mean(test_accuracy)
print("Cross validation trainig score ",np.mean(training_accuracy).round(2))
print("Cross validation test score",np.mean(test_accuracy).round(2))
print("Variance between Training and Testing " ,(ac1-ac2).round(3))

# %%
#cross validation by KNN
#k=15
#cross validation method
#validation set approach
#random state = we wre not shuffling the data
#test_size = 0.30 (train:test = 70:30)
for i in range(1,21,2):
  from sklearn.model_selection import train_test_split
  from sklearn.metrics import accuracy_score
  from sklearn.neighbors import KNeighborsClassifier
  KNN = KNeighborsClassifier(n_neighbors=i)
  training_accuracy = []
  test_accuracy = []
  for p in range(1,101):
    x_train,x_test,y_train,y_test = train_test_split(SS_x,y,test_size=0.30,random_state=p)
    KNN.fit(x_train,y_train)
    y_pred_train = KNN.predict(x_train)
    y_pred_test = KNN.predict(x_test)
    training_accuracy.append(accuracy_score(y_train,y_pred_train))
    test_accuracy.append(accuracy_score(y_test,y_pred_test))
    ac1=np.mean(training_accuracy)
    ac2=np.mean(test_accuracy)
  print("Cross validation Trainig accuracy for ","k =",i,": ",np.mean(training_accuracy).round(2))
  print("Cross validation Test accuracy for ","k =",i,": ",np.mean(test_accuracy).round(2))
  print("Variance between Training and Testing :","for k=",i,":",(ac1-ac2).round(3))
  print(" ")
# Out:
# Cross validation Trainig accuracy for  k = 1 :  1.0
# Cross validation Test accuracy for  k = 1 :  0.85
# Variance between Training and Testing : for k= 1 : 0.148
#
# Cross validation Trainig accuracy for  k = 3 :  0.93
# Cross validation Test accuracy for  k = 3 :  0.86
# Variance between Training and Testing : for k= 3 : 0.07
#
# Cross validation Trainig accuracy for  k = 5 :  0.91
# Cross validation Test accuracy for  k = 5 :  0.86
# Variance between Training and Testing : for k= 5 : 0.052
#
# Cross validation Trainig accuracy for  k = 7 :  0.9
# Cross validation Test accuracy for  k = 7 :  0.86
# Variance between Training and Testing : for k= 7 : 0.039
#
# Cross validation Trainig accuracy for  k = 9 :  0.89
# Cross validation Test accuracy for  k = 9 :  0.86
# Variance between Training and Testing : for k= 9 : 0.032
#
# Cross validation Trainig accuracy for  k = 11 :  0.88
# Cross validation Test accuracy for  k = 11 :  0.85
# ...

# %%
#cross validation method ------------------------- # Decision tree method----------------------------------
#validation set approach
#random state = we wre not shuffling the data
#test_size = 0.30 (train:test = 70:30)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()

training_accuracy = []
test_accuracy = []
for i in range(1,101):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=i)
    dt.fit(x_train,y_train)
    y_pred_train = dt.predict(x_train)
    y_pred_test = dt.predict(x_test)
    training_accuracy.append(accuracy_score(y_train,y_pred_train))
    test_accuracy.append(accuracy_score(y_test,y_pred_test))
    ac1=np.mean(training_accuracy)
    ac2=np.mean(test_accuracy)
print("Cross validation trainig score ",np.mean(training_accuracy).round(3))
print("Cross validation test score",np.mean(test_accuracy).round(3))
print("Variance between Training and Testing :",(ac1-ac2).round(3))
# Out:
# Cross validation trainig score  1.0
# Cross validation test score 0.993
# Variance between Training and Testing : 0.007

# %%
#-------------------Univariate analysis-----------------------------------------------
#constructing box for all x_variables value counts
#Visualizing the data
import matplotlib.pyplot as plt
plt.boxplot(SS_x,vert=False)
plt.title("Box plot for each x variable")
plt.ylabel("values")
plt.show()

# %%
##Bar graph for every x- variable with ShelveLoc
import seaborn as sns
import matplotlib.pyplot as plt
for column in df.select_dtypes(include=["int64"]):
  sns.barplot(x=df['Award'], y=df[column])
  plt.show()

# %%
#Scatter plot for each pair of features
for i, column1 in enumerate(df.select_dtypes(include=["int64"])):
    for column2 in df.select_dtypes(include=["int64"])[i+1:]:
        sns.scatterplot(x=df[column1], y=df[column2])#, hue=df['ShelveLoc'])
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# ------------------------------------------- DBSCAN -----------------------------------------------------------
#Our DBSCAN cluster analysis not only used for forming clusters but also used for
#Identifying outlayers

# %%
df.drop("Target", axis=1, inplace=True)

# %%
#forming group by clusters
x=df.iloc[:,2:]
x.head()
# Out:
#     cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# ID
# 1           1          1          1          174            1
# 2           1          1          1          215            2
# 3           1          1          1         4123            4
# 4           1          1          1          500            1
# 5           4          1          1        43300           26
#
#     Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# ID
# 1                   0                0               7000      0
# 2                   0                0               6968      0
# 3                   0                0               7034      0
# 4                   0                0               6952      0
# 5                2077                4               6935      1

# %%
#standardization will fit the values b/w -3 to +3

from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
SS_x_new = SS.fit_transform(x)
SS_x_new = pd.DataFrame(SS_x_new)
#Assigning Coloumn names
SS_x_new.columns = list(x)
SS_x_new.head()
# Out:
#    cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0  -0.769578  -0.098242  -0.062767    -0.702786    -1.104065
# 1  -0.769578  -0.098242  -0.062767    -0.701088    -0.999926
# 2  -0.769578  -0.098242  -0.062767    -0.539253    -0.791649
# 3  -0.769578  -0.098242  -0.062767    -0.689286    -1.104065
# 4   1.409471  -0.098242  -0.062767     1.083121     1.499394
#
#    Flight_miles_12mo  Flight_trans_12  Days_since_enroll     Award
# 0          -0.328603        -0.362168           1.395454 -0.766919
# 1          -0.328603        -0.362168           1.379957 -0.766919
# 2          -0.328603        -0.362168           1.411920 -0.766919
# 3          -0.328603        -0.362168           1.372208 -0.766919
# 4           1.154932         0.692490           1.363975  1.303918

# %%
from sklearn.cluster import DBSCAN
DBSCAN()
dbscan = DBSCAN(eps=0.75,min_samples=3)
dbscan.fit(SS_x_new)
# Out:
# DBSCAN(eps=0.75, min_samples=3)

# %%
#here DBSCAN itself decides how many clusters are suitable
# if we got (-1) as a lable it means it is a noisy data point ==> outlayer

y= dbscan.labels_
y=pd.DataFrame(y)
y.value_counts()
# Out:
#  0     2373
#  1     1180
# -1      366
#  8       12
#  7        9
#  17       6
#  15       5
#  9        5
#  18       5
#  4        4
#  10       4
#  12       4
#  13       4
#  3        4
#  6        3
#  5        3
#  11       3
#  14       3
#  16       3
#  2        3
# dtype: int64

# %%
#here -1 means., we have found outlayers.
# 193 data points are falling under 0th cluster., which is not so better
# but for better problem solving go for K-Means cluster analysis

# %%
#removing outlayers from y
df["clusters"] = y

# %%
#.copy() is used at the end of the main dataframe
df_new = df[df["clusters"] != -1]
df_new.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1     28143           0          1          1          1          174
# 2     19244           0          1          1          1          215
# 3     41354           0          1          1          1         4123
# 4     14776           0          1          1          1          500
# 5     97752           0          4          1          1        43300
#
#     Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# ID
# 1             1                  0                0               7000      0
# 2             2                  0                0               6968      0
# 3             4                  0                0               7034      0
# 4             1                  0                0               6952      0
# 5            26               2077                4               6935      1
#
#     clusters
# ID
# 1        0.0
# 2        0.0
# 3        0.0
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3637 entries, 1 to 4021
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3637 non-null   int64
#  1   Qual_miles         3637 non-null   int64
#  2   cc1_miles          3637 non-null   int64
#  3   cc2_miles          3637 non-null   int64
#  4   cc3_miles          3637 non-null   int64
#  5   Bonus_miles        3637 non-null   int64
#  6   Bonus_trans        3637 non-null   int64
#  7   Flight_miles_12mo  3637 non-null   int64
#  8   Flight_trans_12    3637 non-null   int64
#  9   Days_since_enroll  3637 non-null   int64
#  10  Award              3637 non-null   int64
#  11  clusters           3614 non-null   float64
# dtypes: float64(1), int64(11)
# memory usage: 369.4 KB

# %%
#drop the cluster column
#df_new.drop(df.columns[[5]],axis=1,inplace=True)

# %%
x_new=df_new.iloc[:,0:2]
from sklearn.cluster import KMeans
cluster=KMeans(n_init=20,n_clusters=5)
y=cluster.fit_predict(x_new)
y
# Out:
# array([0, 0, 0, ..., 4, 0, 0], dtype=int32)

# %%
y=pd.DataFrame(y)
y.value_counts()
# Out:
# 0    2306
# 4     930
# 1     301
# 3      83
# 2      17
# dtype: int64

# %%
#seeing clusters in scatter plot
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
plt.scatter(x_new.iloc[:,0],x_new.iloc[:,1],c=cluster.labels_,cmap='rainbow')
plt.xlabel("X-LABEL")
plt.ylabel("Y-LABEL")
plt.show()

# %%
cluster.inertia_
# Out:
# 3538339730046.792

# %%
#Inertias for elbow plot
kinertias = []
for i in range(1,11):
  from sklearn.cluster import KMeans
  cluster=KMeans(n_init=20,n_clusters=i)
  cluster.fit_predict(x_new)
  kinertias.append(cluster.inertia_)
kinertias
# Out:
# [36945892352619.63,
#  16868005083785.836,
#  8882769038818.13,
#  5133957172140.034,
#  3538220609087.174,
#  2511695112384.1978,
#  1765116903531.6514,
#  1414696856870.9893,
#  1165959044577.5386,
#  910842143540.0413]

# %%
#making with k - means cluster
from sklearn.cluster import KMeans
cluster=KMeans(n_init=20,n_clusters=5)
y_kmens=cluster.fit_predict(x_new)
y_kmens
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int32)

# %%
y_kmens=pd.DataFrame(y_kmens)
y_kmens.value_counts()
print(len(y_kmens))
print(len(df_new))
#y_kmens.tail()
# Out:
# 3637
# 3637

# %%
#seeing Inertias in scatter/screw/elbow plot
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
plt.scatter(range(1,11),kinertias)
plt.plot(range(1,11),kinertias,color='red')
plt.show()

# %%
df_new.loc[:, 'Target'] = y_kmens.values
df_new["Target"]
# Out:
# <ipython-input-106-c497b6f2453b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.loc[:, 'Target'] = y_kmens.values
# ID
# 1       0
# 2       0
# 3       0
# 4       0
# 5       1
#        ..
# 4017    0
# 4018    1
# 4019    1
# 4020    0
# 4021    0
# Name: Target, Length: 3637, dtype: int32

# %%
df_new.tail()
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID
# 4017            4                200                1               1403
# 4018            5                  0                0               1395
# 4019            8                  0                0               1402
# 4020            1                500                1               1401
# 4021            0                  0                0               1398
#
#       Award  clusters  Target
# ID
# 4017      1       NaN       0
# ...

# %%
#Label Encoding the obj Dtypes
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for column in df_new.select_dtypes(include=["object"]):
    df_new[column] = LE.fit_transform(df_new[column])
df_new.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1     28143           0          1          1          1          174
# 2     19244           0          1          1          1          215
# 3     41354           0          1          1          1         4123
# 4     14776           0          1          1          1          500
# 5     97752           0          4          1          1        43300
#
#     Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# ID
# 1             1                  0                0               7000      0
# 2             2                  0                0               6968      0
# 3             4                  0                0               7034      0
# 4             1                  0                0               6952      0
# 5            26               2077                4               6935      1
#
#     clusters  Target
# ID
# 1        0.0       0
# ...

# %%
#choosing X and Y variables
y=df_new["Target"]
x=df_new.iloc[:,0:-2]
x.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1     28143           0          1          1          1          174
# 2     19244           0          1          1          1          215
# 3     41354           0          1          1          1         4123
# 4     14776           0          1          1          1          500
# 5     97752           0          4          1          1        43300
#
#     Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# ID
# 1             1                  0                0               7000      0
# 2             2                  0                0               6968      0
# 3             4                  0                0               7034      0
# 4             1                  0                0               6952      0
# 5            26               2077                4               6935      1

# %%
#standardization will fit the values b/w -3 to +3

from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
SS_x = SS.fit_transform(x)
SS_x = pd.DataFrame(SS_x)
#giving columns names to the converted data
SS_x.columns = list(x)
SS_x.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0 -0.450015   -0.187879  -0.768458  -0.099369  -0.065829    -0.698752
# 1 -0.538311   -0.187879  -0.768458  -0.099369  -0.065829    -0.697064
# 2 -0.318934   -0.187879  -0.768458  -0.099369  -0.065829    -0.536197
# 3 -0.582643   -0.187879  -0.768458  -0.099369  -0.065829    -0.685332
# 4  0.240651   -0.187879   1.413339  -0.099369  -0.065829     1.076461
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0    -1.096785          -0.323845        -0.357690           1.426128
# 1    -0.993239          -0.323845        -0.357690           1.410497
# 2    -0.786147          -0.323845        -0.357690           1.442736
# 3    -1.096785          -0.323845        -0.357690           1.402681
# 4     1.491865           1.131037         0.688276           1.394377
#
#       Award
# 0 -0.761982
# 1 -0.761982
# 2 -0.761982
# 3 -0.761982
# 4  1.312366

# %%
#cross validation method ------------------------- # Decision tree method----------------------------------
#validation set approach
#random state = we wre not shuffling the data
#test_size = 0.30 (train:test = 70:30)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()

training_accuracy = []
test_accuracy = []
for i in range(1,101):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=i)
    dt.fit(x_train,y_train)
    y_pred_train = dt.predict(x_train)
    y_pred_test = dt.predict(x_test)
    training_accuracy.append(accuracy_score(y_train,y_pred_train))
    test_accuracy.append(accuracy_score(y_test,y_pred_test))
    ac1=np.mean(training_accuracy)
    ac2=np.mean(test_accuracy)
print("Cross validation trainig score ",np.mean(training_accuracy).round(3))
print("Cross validation test score",np.mean(test_accuracy).round(3))
print("Variance between Training and Testing :",(ac1-ac2).round(3))
# Out:
# Cross validation trainig score  1.0
# Cross validation test score 1.0
# Variance between Training and Testing : 0.0

# %%
# DBSCAN giving the better results, as it helps in removing the outliers
